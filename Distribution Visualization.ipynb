# %% [markdown]
# ## Name:- Sandeep Sharma

# %% [markdown]
# ### Distribution Visualization
#
# Discrete and Continuous Variables
#
# A discrete variable is a variable that can only take certain values. If you can count a set of items, then it’s a discrete variable. e.g., The number of students in a class
#
# A continuous variable takes on an any values. e.g., Height, length
#
# In stats we represent distribution of discrete variables with PMF (Probability Mass Functions) and continuous variables with PDF (Probability Density Functions).
#
#
#
#
#
#
# Visualizing a PMF of a binomial distribution.
#
# The PMF of a binomial distribution in function form:

# %%
import numpy as np
import math
import scipy
from scipy.stats import sem, binom
import matplotlib.pyplot as plt

# %% [markdown]
# #### PMF Visualization

# %%
n = 100
p = 0.5

# %%
fig, ax = plt.subplots(1, 1, figsize=(17,5))
x = np.arange(binom.ppf(0.01, n, p), binom.ppf(0.99, n, p))
ax.plot(x, binom.pmf(x, n, p), 'bo', ms=8, label='Binomial PMF')
ax.vlines(x, 0, binom.pmf(x, n, p), colors='b', lw=5, alpha=0.5)
rv = binom(n, p)
ax.legend(loc='best', frameon=False)
plt.title('PMF of a binomial distribution', fontsize='xx-large')
plt.show()

# %% [markdown]
# #### Visualizing a simple normal distribution with a mean of 0 and standard deviation of 1.
#
# PDF of a normal distribution in formula form

# %% [markdown]
# ### PDF normal distribution

# %%
mu = 0
variance = 1
sigma = math.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)

# %%
plt.figure(figsize=(16,5))
plt.plot(x, scipy.stats.norm.pdf(x, mu, sigma), label='Normal Distribution')
plt.title('Normal Distribution with mean = 0 and std = 1')
plt.legend(fontsize='xx-large')
plt.show()
